# %% [markdown]
# ### CONTEXT
# OneU là 1 loyalty app mang đến vô số voucher với các scheme hấp dẫn cho user. Voucher là 1 trong số nhiều use case của app & được cung cấp bởi các thương hiệu thuộc nhiều lĩnh vực trong đời sống. Mục tiêu của use case này là mang đến đa dạng các scheme/offering cho nhiều người dùng tại Việt Nam nhằm giúp họ tiếp cận được những sản phẩm và dịch vụ phù hợp, qua đó, có thể nâng cao chất lượng cuộc sống qua từng ngày.
# Các merchant/voucher được phân loại vào các category/sub-category khác nhau. Mỗi voucher có 1 voucher code và gồm nhiều serial number. Khách hàng có thể claim/redeem nhiều serial number thuộc cùng 1 hoặc nhiều voucher.
# Với các dữ liệu được cung cấp, hãy giúp phân tích:
# 1.	Tình hình hoạt động của use case Voucher trên OneU.
# 2.	Category, Sub-category, voucher nào đang perform tốt trên ứng dụng.
# 3.	Category, Sub-category, voucher phù hợp với tập người dùng nào.
# ### Ứng viên vui lòng gửi lại git repo chứa bài làm, bao gồm nhưng không giới hạn:
# 1.	01 dashboard cho use case Voucher
# 2.	Technical files thể hiện các phân tích/visualisation/coding đã thực hiện
# 3.	01 presentation file để thuyết trình bài làm

# %% [markdown]
# # Tools sử dụng dựa vào bài toán
# ### Phân tích
# - Python
# ### Dashboard
# - Python: Drap Phân tích
# - Dashboard: Nhanh thì excel, PowerBi, kĩ thì Python Dash/Plotly
# ### Presentation File để thuyết trình
# - PowerPoint/Canva hoặc Jupyter

# %% [markdown]
# # **DATE DEFINITION & DESCRIPTION**
# ## Describe general information on what each table contains
# - fact: Information about users' actions (claim/redeemed) for voucher types
# - scheme: Information about promotion schemes/campaigns corresponding to voucher types (scheme description, voucher value, scheme type)
# - voucher: stocking of voucher types, information on limited dates
# - merchant: information about categories and sub-categories of merchants
# - user: user information
#
# ## Indepth definition of each column definition from each table
# ### *fact*
# - TRANSACTION_ID: ID of the transaction
# - SERIAL_NUMBER: Serial of the goods? Because the number is more than the USER_ID number, it is less than the Voucher number
# - VOUCHER_CODE: Code of Voucher-266
# - VOUCHER_NAME: Name of Voucher-254, because there are more voucher names than codes, so some voucher names have many codes
# - AVAILABLE_FROM: Voucher's effective date.
# - AVAILABLE_TO: Voucher validity period expires.
# - MERCHANT_CODE: code of merchandise
# - ACTION: Claim action (Receive/Own Voucher by clicking on receive while Voucher is being distributed) or Redeem Voucher (Use/Apply Voucher depending on Voucher features)
# - CALENDAR_DIM_ID: ...
# - USER_ID: ID code of the account/user used by the shopper
# ### *scheme*
# - discount_type: discount type
# - discount_anunt: discount amount (if discount is a direct value)
# - discount_percent: % discount (% discount does not include discounts with accompanying gifts or direct value discounts...possible)
# - description: description of the campaign scheme (the service being promoted may include) and information about the voucher's effects
# - VOUCHER_CODE: voucher code
# ### *voucher*
# - voucher_code: voucher code
# - total_stock: total number of vouchers available
# - display_date_from: start date displayed on the app so you can claim
# - display_date_to: end date displayed on app
# ### *merchant*
# - MERCHANT_CODE: code of merchandise
# - category: business industry 1
# - sub-category: business sector 2 (deep classification0
# ### *user*
# - gender: customer's gender
# - user_id: Customer ID
# - province_name: province where you live
# - age: age of customer

# %% [markdown]
# # Phân tích objectives
#
# ### Tình hình hoạt động của use case Voucher trên OneU
# - Tình hình hoạt động của Voucher nghĩa là gì?
#
#
# ### Category, Sub-category, voucher nào đang perform tốt trên ứng dụng.
# - Các Category, Sub-category của Voucher là gì?
# - Định nghĩa như thế nào là perform tốt?
# ### Category, Sub-category, voucher phù hợp với tập người dùng nào.
# - Các tập người dùng ở đây là gì?
# - Phù hợp ở đây nghĩa là gì? Thể hiện bằng metrics nào?

# %% [markdown]
# Feature Engineer ideas
# Columns to generate features:
# Datetime column: AVAILABLE_FROM/TO, CALENDAR_DIM_ID
# TEXT: VOUCHER_CODE, VOUCHER_NAME, MERCHANT_CODE

# %% [markdown]
# ## PERPLEXITY
#
# ### Problem Statement
# The objective of this analysis is to evaluate the performance of an e-commerce platform's voucher system. This involves understanding how vouchers operate, identifying which categories and vouchers are most effective, and determining the best voucher types for different customer segments.
#
# ### Data Overview
# The dataset is composed of five interconnected tables:
#
# - **fact**: Captures user interactions with vouchers, including claims and redemptions.
# - **scheme**: Details promotion schemes associated with each voucher, including discount types and amounts.
# - **voucher**: Contains information about the inventory of vouchers, including their availability.
# - **merchant**: Provides details about the categories and subcategories of the merchants offering vouchers.
# - **user**: Contains demographic information about users, such as gender, age, and location.
#
# ### Data Issues and Assumptions
# - **SERIAL_NUMBER**: Its relevance is unclear and may not be essential for analysis.
# - **VOUCHER_NAME**: Ambiguity arises from multiple codes sharing the same name, complicating analysis.
# - **CALENDAR_DIM_ID**: The purpose of this column is not defined.
# - **Discount Types**: The lack of detail regarding discount types may hinder the analysis of their effectiveness.
# - **Discount Amount vs. Percentage**: Clarification is needed on how these metrics relate and their applicability in various contexts.
#
# ## Analysis Objectives and Metrics
#
# ### Objective 1: Assess Voucher Operation
# **Questions:**
# 1. How many vouchers are currently active?
# 2. is the redemption rate of vouchers?
# 3. What are the overall claim and redemption rates for vouchers?
# 4. How do these rates vary over time?
# 5. What is the average discount of redeemed vouchers, and how does it influence redemption rates?
# 6. Does the validity period of vouchers affect their claim and redemption rates?
#
# **Metrics:**
# - Total vouchers issued, claimed, and redeemed.
# - Total active vouchers (calculated from `voucher` table using `display_date_from` and `display_date_to`)
# - Claim rate = (Total claimed vouchers / Total issued vouchers) * 100.
# - Redemption rate = (Total redeemed vouchers / Total claimed vouchers) * 100.
# - Average discount amount and percentage = Sum of `discount_amount` or `discount_percent` from the `scheme` table for redeemed vouchers.
# - Average validity period of vouchers.
# - Claim and redemption rates segmented by time (daily, weekly, monthly).
#
# **Combinations of Features:**
# - Join `fact`, `voucher`, and `scheme` tables using `VOUCHER_CODE`.
# - Analyze voucher usage across demographics by incorporating the `user` table.
#
# ### Objective 2: Identify High-Performing Categories and Vouchers
# **Questions:**
# 1. Which merchant categories and subcategories exhibit the highest claim and redemption rates?
# 2. What is the average discount offered per category?
# 3. What types of vouchers (by discount type and amount) are most effective?
# 4. How do various voucher schemes (e.g., for new users, based on purchase amount) perform?
#
# **Metrics:**
# - Claim and redemption rates by category and subcategory.
# - Average discount amount and percentage by category and subcategory.
# - Voucher performance metrics by discount type and amount.
# - Scheme performance metrics, including conversion rates and average order values.
#
# **Combinations of Features:**
# - Join `fact`, `merchant`, `voucher`, and `scheme` tables to analyze performance based on category and subcategory.
#
# ### Objective 3: Customer Segmentation and Voucher Targeting
# **Questions:**
# 1. What are the key customer segments based on demographics and behavior?
# 2. Which voucher types are favored by different customer segments?
# 3. How do targeted voucher campaigns influence customer behavior?
#
# **Metrics:**
# - Customer segments based on demographics (age, gender, location) and behavior (purchase frequency, average order value, redemption rates).
# - Average discount value redeemed by each segment.
# - Voucher claim and redemption rates by customer segment.
# - Impact of targeted campaigns on sales and customer retention.
#
# **Combinations of Features:**
# - Join `fact`, `user`, `merchant`, and `scheme` tables to group customers by demographics and analyze voucher preferences.
#
#
# ## Additional Insights and Potential Questions
# 1. **Seasonal trend/Peak Times for Voucher Claims and Redemptions:**
#    - Analyzing redemption rates over time can reveal seasonal patterns.
#    - Analyze `CALENDAR_DIM_ID` and `ACTION` columns in the `fact` table.
#    - Metrics: Claims and redemptions by time of day and day of the week.
#
# 2. **Voucher Performance by Province:**
#    - Utilize the `province_name` column in the `user` table.
#    - Metrics: Claims and redemptions by province, redemption rates by province.
#
# 3. **Effectiveness of Different Discount Types/How do different discount types affect redemption rates?:**
#    - Comparing percentage discounts vs. fixed amount discounts can yield insights into customer preferences.
#    - Investigate `discount_type`, `discount_amount`, and `discount_percent` in the `scheme` table.
#    - Metrics: Redemptions by discount type, average redemption rates by type.
#
# 4. **Impact of Competition and Voucher Fraud:**
#    - Explore external factors and potential fraudulent activities affecting voucher performance.
#
# 5. **Effectiveness of Distribution Channels:**
#    - Metrics: Compare performance of vouchers distributed via app notifications, email, and social media.
#
# 6. **What is the impact of promotional campaigns on voucher redemption?**
#    - Evaluating the effectiveness of different promotional schemes can help refine marketing strategies.
#
#
# ## Dashboard Design for Stakeholders
#
# To effectively communicate insights from the analysis, the dashboard should include the following metrics and visualizations:
#
# ### **Key Metrics to Display:**
#
# - **Operational Status:**
#   - Effectiveness of different discount types.
#   - Total active/expired vouchers
#   - Redemption rate (percentage)
#   - Average discount value of redeemed vouchers
#   - Total number of vouchers claimed and redeemed.
#   - Claim-to-redemption ratio.
#   - Voucher usage rate.
#   - Voucher performance by province.
#
# - **Performance by Category:**
#   - Claims and redemptions by category and subcategory.
#   - Redemption rates by category and subcategory (bar chart)
#   - Average discount per category (line chart)
#   - Revenue generated from redeemed vouchers by category and subcategory.
#
# - **Customer Segmentation:**
#   - Total vouchers redeemed by demographic segments (pie chart)
#   - Average discount value redeemed by segment (bar chart)
#   - Preferred categories and subcategories by customer group.
#   - Customer segmentation metrics.
#
# - **Other**
#   - Peak times for voucher activity.
#
# ### **Graph Types:**
#
# - **Bar Charts**: For comparing redemption rates and average discounts across categories and customer segments.
# - **Line Charts**: To visualize trends in claim and redemption rates over time.
# - **Pie Charts**: To illustrate the distribution of voucher types or customer segments.
# - **Heatmaps**: To analyze relationships between variables, such as category versus discount.
#
# ### **Layout Suggestions:**
#
# - **Top Section:** Overview of operational status with key metrics.
# - **Middle Section:** Performance analysis by category and subcategory.
# - **Bottom Section:** Insights into customer segmentation and voucher preferences.
#
# This revised analysis provides a comprehensive framework for evaluating the e-commerce platform's voucher system, enhancing clarity and depth in understanding the data while offering actionable insights for stakeholders.

# %% [markdown]
# # CHATGPT
#
# To analyze this dataset effectively, we'll first define the objectives of the analysis and the questions we aim to answer. We'll also identify the relevant metrics and the combinations of features that will provide insights into these questions. Finally, we'll design a dashboard to present our findings to stakeholders.
#
# ### Data Overview
# The dataset consists of five tables:
#
# - **fact**: Contains information about user interactions with vouchers (claim, redeem).
# - **scheme**: Describes promotion schemes and voucher details.
# - **voucher**: Contains voucher inventory information.
# - **merchant**: Provides merchant category and subcategory information.
# - **user**: Contains user demographics (gender, age, province).
#
# ### Data Issues and Assumptions
# - **SERIAL_NUMBER**: The purpose of this column is unclear and might be redundant.
# - **VOUCHER_NAME**: Multiple voucher codes can share the same name, which might introduce ambiguity.
# - **CALENDAR_DIM_ID**: This column is not defined and its purpose is unclear.
# - **discount_type**: The specific types of discounts are not detailed.
# - **discount_amount** and **discount_percent**: It's unclear how these columns relate to each other and which one is applicable in different scenarios.
#
# ## Main Questions and Metrics
#
# ### Objective 1: Assess Voucher Operation
# **Questions:**
# 1. What is the overall voucher claim and redemption rate?
# 2. How do voucher claim and redemption rates vary over time?
# 3. What is the average voucher discount and its impact on redemption rates?
# 4. How does the voucher validity period affect claim and redemption rates?
#
# **Metrics:**
# - Total vouchers issued, claimed, and redeemed
# - Number of active/expired vouchers (currently available for use)
# - Claim (Usage) rate = (total claimed vouchers / total issued vouchers) * 100
# - Redemption rate = (total redeemed vouchers / total claimed vouchers) * 100
# - Average discount amount/percentage
# - Average voucher validity period
# - Claim and redemption rates by time period (daily, weekly, monthly)
#
# **Combinations of Features:**
# - Join the `fact`, `voucher`, and `scheme` tables using `VOUCHER_CODE`.
# - Use the `user` table to analyze voucher usage across different user demographics.
#
# **Approach:**
# - Aggregate the number of claimed and redeemed vouchers from the `fact` table.
# - Calculate the claim-to-redemption ratio by dividing the total number of redeemed vouchers by the total number of claimed vouchers.
# - Determine active and expired vouchers using the `voucher` table's `display_date_to` and `available_to` columns.
# - Use voucher usage rate to understand the effectiveness of the vouchers.
#
#
# ### Objective 2: Identify High-Performing Categories and Vouchers
# **Questions:**
# 1. Which merchant categories and subcategories have the highest voucher claim and redemption rates?
# 2. Which voucher types (discount type, amount) are most effective
# 3. How do different voucher schemes (e.g., new user, purchase amount) perform?
#
# **Metrics:**
# - Number of vouchers claimed and redeemed, Claim and redemption rates by category and subcategory
# - Average discount amount/percentage by category and subcategory
# - Voucher claim and redemption rates by discount type and amount
# - Scheme performance metrics (e.g., conversion rate, average order value)
#
# **Combinations of Features:**
# - Join the `fact`, `merchant`, `voucher`, and `scheme` tables.
# - Analyze voucher performance by category and subcategory based on the `merchant` table's `category` and `sub-category` columns.
#
# **Approach:**
# - Aggregate the number of claimed and redeemed vouchers by `category` and `sub-category`.
# - Calculate the redemption rate by dividing the number of redeemed vouchers by the number of claimed vouchers for each category and subcategory.
# - Calculate the average discount value using `discount_amount` and `discount_percent` from the `scheme` table.
# - Estimate revenue generated from redeemed vouchers using the discount values and the number of redemptions.
#
# ### Objective 3: Customer Segmentation and Voucher Targeting
# **Questions:**
# 1. What are the key customer segments based on demographics and behavior?
# 2. Which voucher types are preferred by different customer segments?
# 3. What is the impact of targeted voucher campaigns on customer behavior?
#
# **Metrics:**
# - Customer segmentation based on demographics (age, gender, location)
# - Voucher claim and redemption rates/number by customer segment
# - Preferred categories and subcategories by each customer group
# - Lift in sales and customer retention for targeted voucher campaigns
#
# **Combinations of Features:**
# - Join the `fact`, `user`, `merchant`, and `scheme` tables to analyze customer preferences for different vouchers.
# - Group customers by demographics using the `user` table's `age`, `gender`, and `province_name` columns.
#
# **Approach:**
# - Perform customer segmentation based on demographics.
# - Aggregate the number of claimed and redeemed vouchers for each customer segment.
# - Calculate the redemption rate for each customer segment.
# - Identify preferred categories and subcategories by analyzing the number of vouchers claimed and redeemed by each customer group.
#
# ## Additional Questions and Insights
#
# 1. **What is the peak time for voucher claims and redemptions?**
#    - Analyze the `CALENDAR_DIM_ID` and `ACTION` columns in the `fact` table to determine peak times for voucher activity.
#    - Metrics: Number of claims and redemptions by time of day and day of the week.
#
# 2. **How does voucher performance vary by province?**
#    - Use the `user` table's `province_name` column to analyze voucher performance across different regions.
#    - Metrics: Number of claims and redemptions by province, redemption rate by province.
#
# 3. **Which discount types are most effective?**
#    - Analyze the `discount_type` and `discount_amount`/`discount_percent` columns in the `scheme` table.
#    - Metrics: Number of redemptions by discount type, average redemption rate by discount type.
#
#
#
# ## Dashboard Design
#
# ## Additional Insights and Potential Questions
# 1. **Peak Time for Voucher Claims and Redemptions:**
#    - Analyze the `CALENDAR_DIM_ID` and `ACTION` columns in the `fact` table.
#    - Metrics: Number of claims and redemptions by time of day and day of the week.
#
# 2. **Voucher Performance by Province:**
#    - Use the `user` table's `province_name` column.
#    - Metrics: Number of claims and redemptions by province, redemption rate by province.
#
# 3. **Effectiveness of Different Discount Types:**
#    - Analyze the `discount_type`, `discount_amount`, and `discount_percent` columns in the `scheme` table.
#    - Metrics: Number of redemptions by discount type, average redemption rate by discount type.
#
# 4. **Impact of Competition and Voucher Fraud:**
#    - Investigate external factors and potential fraudulent activities impacting voucher performance.
#
# 5. **Effectiveness of Distribution Channels:**
#    - Metrics: Performance comparison of vouchers distributed via app notifications, email, and social media.
#
# ### Key Metrics to Display
# - Total number of vouchers claimed and redeemed
# - Claim-to-redemption ratio
# - Number of active and expired vouchers
# - Voucher usage rate
# - Number of vouchers claimed and redeemed by category and subcategory
# - Redemption rate by category and subcategory
# - Average discount value by category and subcategory
# - Revenue generated from redeemed vouchers by category and subcategory
# - Customer segmentation metrics
# - Preferred categories and subcategories by customer group
# - Peak times for voucher activity
# - Voucher performance by province
# - Effectiveness of different discount types
#
# - **Bar Charts**: Compare categories, voucher types, and customer segments.
# - **Line Charts**: Show trends over time (e.g., claim/redemption rates).
# - **Pie Charts**: Show distribution of voucher types or customer segments.
# - **Heatmaps**: Analyze relationships between variables (e.g., category vs. discount).
#
# This comprehensive approach will help stakeholders understand the current status and performance of vouchers on the app, identify high-performing categories and customer preferences, and make data-driven decisions to optimize voucher strategies.

# %% [markdown]
# # GOOGLE GEMINI
# ## Understanding the Problem and Data
#
# ### Problem Statement
# The goal is to analyze an e-commerce platform's voucher system to understand its performance, identify high-performing categories and vouchers, and determine suitable voucher types for different customer segments.
#
# ### Data Overview
# The dataset consists of five tables:
#
# * **fact**: Contains information about user interactions with vouchers (claim, redeem).
# * **scheme**: Describes promotion schemes and voucher details.
# * **voucher**: Contains voucher inventory information.
# * **merchant**: Provides merchant category and subcategory information.
# * **user**: Contains user demographics (gender, age, province).
#
# ### Data Issues and Assumptions
# * **SERIAL_NUMBER**: The purpose of this column is unclear and might be redundant.
# * **VOUCHER_NAME**: Multiple voucher codes can share the same name, which might introduce ambiguity.
# * **CALENDAR_DIM_ID**: This column is not defined and its purpose is unclear.
# * **discount_type**: The specific types of discounts are not detailed.
# * **discount_anunt** and **discount_percent**: It's unclear how these columns relate to each other and which one is applicable in different scenarios.
#
# ## Analysis Objectives and Metrics
#
# ### Objective 1: Assess Voucher Operation
# * **Questions:**
#   * What is the overall voucher claim and redemption rate?
#   * How does voucher claim and redemption rate vary over time?
#   * What is the average voucher discount and its impact on redemption rate?
#   * How does voucher validity period affect claim and redemption rates?
# * **Metrics:**
#   * Total vouchers issued, claimed, and redeemed
#   * Claim rate = (total claimed vouchers / total issued vouchers) * 100
#   * Redemption rate = (total redeemed vouchers / total claimed vouchers) * 100
#   * Average discount amount/percentage
#   * Average voucher validity period
#   * Claim and redemption rate by time period (daily, weekly, monthly)
#
# ### Objective 2: Identify High-Performing Categories and Vouchers
# * **Questions:**
#   * Which merchant categories and subcategories have the highest voucher claim and redemption rates?
#   * Which voucher types (discount type, amount) are most effective?
#   * How do different voucher schemes (e.g., new user, purchase amount) perform?
# * **Metrics:**
#   * Claim and redemption rate by category and subcategory
#   * Average discount amount/percentage by category and subcategory
#   * Voucher claim and redemption rate by discount type and amount
#   * Scheme performance metrics (e.g., conversion rate, average order value)
#
# ### Objective 3: Customer Segmentation and Voucher Targeting
# * **Questions:**
#   * What are the key customer segments based on demographics and behavior?
#   * Which voucher types are preferred by different customer segments?
#   * What is the impact of targeted voucher campaigns on customer behavior?
# * **Metrics:**
#   * Customer segmentation based on demographics (age, gender, location) and behavior (purchase frequency, average order value, voucher redemption rate)
#   * Voucher claim and redemption rate by customer segment
#   * Lift in sales and customer retention for targeted voucher campaigns
#
# ## Feature Combinations for Analysis
#
# * **Voucher performance analysis:**
#   * Voucher code, voucher name, discount type, discount amount, discount percent, available from, available to, claim count, redeem count, redemption rate, claim rate
# * **Category performance analysis:**
#   * Merchant code, category, subcategory, voucher code, claim count, redeem count, redemption rate, claim rate, average discount
# * **Customer segmentation:**
#   * User ID, gender, age, province, purchase history, voucher claim/redeem history
#
# ## Additional Insights and Dashboard Design
#
# ### Potential Additional Questions
#
# * How does competition from other platforms impact voucher performance?
# * What is the impact of voucher fraud on the platform?
# * How effective are different voucher distribution channels (app notifications, email, social media)?
#
# ### Dashboard Design
#
# * **Overview:**
#   * Key performance indicators (KPIs): total vouchers, claims, redemptions, claim/redemption rates
#   * Trend analysis of voucher metrics over time
# * **Category Performance:**
#   * Category-wise claim and redemption rates
#   * Average discount by category
# * **Customer Segmentation:**
#   * Customer segments based on demographics and behavior
#   * Voucher preference by segment
# * **Voucher Effectiveness:**
#   * Voucher type performance (discount type, amount)
#   * Scheme performance (e.g., new user, purchase amount)
#
# ### Visualization Techniques
#
# * **Bar charts:** Compare categories, voucher types, and customer segments
# * **Line charts:** Show trends over time (e.g., claim/redemption rates)
# * **Pie charts:** Show distribution of voucher types or customer segments
# * **Heatmaps:** Analyze relationships between variables (e.g., category vs. discount)
#
# By addressing these questions and utilizing the suggested metrics and visualizations, we can gain valuable insights into the voucher system's performance and identify opportunities for improvement.
